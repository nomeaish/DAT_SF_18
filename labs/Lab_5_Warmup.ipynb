# %%
import pandas as pd

# %%
df = pd.read_csv('data/lab5warmupdata.txt', delimiter='\t')

# %%
df.head()
# Out:
#   number1  number2
# 0   0,589  '0,589'
# 1   0,578  '0,578'
# 2   7,779  '7,779'
# 3   0,139  '0,139'
# 4   1,687  '1,687'

# %% [markdown]
# ####Exercise 1: Strip the extra comma from the number1 column and convert to integer

# %%
#Your code here
type_of = type(df.number1[0])
type_of
# Out:
# str

# %%
# # method 1 using functions
# def strip(x):
#     return x.str.replace(",","")

# df.number1 = strip(df.number1).astype(int)
# df

# %%
#Bonus: Do it a different way
# method 2: using lambda
df.number1 = df.number1.apply(lambda x : x.replace(",","")).astype(int)
df
# Out:
#     number1  number2
# 0       589  '0,589'
# 1       578  '0,578'
# 2      7779  '7,779'
# 3       139  '0,139'
# 4      1687  '1,687'
# 5      3246  '3,246'
# 6       254  '0,254'
# 7      3133  '3,133'
# 8      9446  '9,446'
# 9      6241  '6,241'
# 10     4922  '4,922'
# 11     4657  '4,657'
# 12     5134  '5,134'
# 13     4947  '4,947'
# 14     5988  '5,988'
# 15     1376  '1,376'
# 16      291  '0,291'
# 17     1515  '1,515'
# 18     3126  '3,126'
# 19      853  '0,853'
# 20     2768  '2,768'
# 21     6738  '6,738'
# 22     8168  '8,168'
# 23      181  '0,181'
# 24     6760  '6,760'
# 25     2199  '2,199'
# 26     2207  '2,207'
# 27     5145  '5,145'
# 28     8247  '8,247'
# 29     7646  '7,646'
# 30      941  '0,941'
# 31     1886  '1,886'
# 32     4981  '4,981'
# 33     2140  '2,140'
# 34     6987  '6,987'
# 35      326  '0,326'
# 36     2867  '2,867'
# 37     4890  '4,890'
# 38     8625  '8,625'
# 39     4475  '4,475'
# 40      903  '0,903'

# %% [markdown]
# ####Exercise 2: Strip the extra quotation marks from the column2 and convert to integer

# %%
#Your code here
# first remove ''
df.number2 = df.number2.apply(lambda x : x.replace("'",""))
# then remove the ',' and convert the type to integer
df.number2 = df.number2.apply(lambda x : x.replace(",","")).astype(int)

df
# Out:
#     number1  number2
# 0       589      589
# 1       578      578
# 2      7779     7779
# 3       139      139
# 4      1687     1687
# 5      3246     3246
# 6       254      254
# 7      3133     3133
# 8      9446     9446
# 9      6241     6241
# 10     4922     4922
# 11     4657     4657
# 12     5134     5134
# 13     4947     4947
# 14     5988     5988
# 15     1376     1376
# 16      291      291
# 17     1515     1515
# 18     3126     3126
# 19      853      853
# 20     2768     2768
# 21     6738     6738
# 22     8168     8168
# 23      181      181
# 24     6760     6760
# 25     2199     2199
# 26     2207     2207
# 27     5145     5145
# 28     8247     8247
# 29     7646     7646
# 30      941      941
# 31     1886     1886
# 32     4981     4981
# 33     2140     2140
# 34     6987     6987
# 35      326      326
# 36     2867     2867
# 37     4890     4890
# 38     8625     8625
# 39     4475     4475
# 40      903      903

# %%
# Confirming that the type of the values in each cell of both the columns in integer
num1 = type(df.number1[0])
num2 = type (df.number2[0])
num1
num2
# Out:
# numpy.int64
