# %% [markdown]
# # GA Data Science 18 (DAT18) - Lab4

# %% [markdown]
# ## Lab goals
#
# - Simple APIs with Python
# - Kimono Labs: an external tool for aquiring data

# %%
# Imports at the top
import json
import urllib
import pandas as pd

# used to import html requests
import requests
import json

# %% [markdown]
# ## Using Python APIs

# %% [markdown]
# ### Either Use Sheetsu or an API you've found
# Sheetsu: Turning Google Docs into APIs/
# https://sheetsu.com/

# %% [markdown]
# ### Using Sheetsu
# I've created a GoogleDoc with wine data
#
# https://docs.google.com/spreadsheets/d/1_U-DHIrBXN8A1e3NbyOIJRORge2udmmaa8qS9mKddWo/edit#gid=0
# https://sheetsu.com/apis/79656330

# %%
# You can either post or get info from this API
# using the /column/Name you can pull only specfic subsets of the data
api_base_url = 'https://sheetsu.com/apis/79656330'
api_column = '/column/Name'

# %% [markdown]
# ##### Reading Data from an API datafeed

# %%
# What kind of data is this returning?
api_response = requests.get(api_base_url)
api_response.text
# Out:
# u'{"status":200,"success":true,"result":[{"Color":"W","Region":"Portugal","Country":"Portugal","Vintage":"2013","Vinyard":"Vinho Verde","Name":"","Grape":"","Consumed In":"2015","Score":"4","Price":""},{"Color":"W","Region":"France","Country":"France","Vintage":"2013","Vinyard":"Peyruchet","Name":"","Grape":"","Consumed In":"2015","Score":"3","Price":"17.8"},{"Color":"W","Region":"Oregon","Country":"Oregon","Vintage":"2013","Vinyard":"Abacela","Name":"","Grape":"","Consumed In":"2015","Score":"3","Price":"20"},{"Color":"W","Region":"Spain","Country":"Spain","Vintage":"2012","Vinyard":"Ochoa","Name":"","Grape":"chardonay","Consumed In":"2015","Score":"2.5","Price":"7"},{"Color":"R","Region":"","Country":"US","Vintage":"2012","Vinyard":"Heartland","Name":"Spice Trader","Grape":"chiraz, cab","Consumed In":"2015","Score":"3","Price":"6"},{"Color":"R","Region":"California","Country":"US","Vintage":"2012","Vinyard":"Crow Canyon","Name":"","Grape":"cab","Consumed In":"2015","Score":"3.5","Price":"13"},{"Color":"R","Region":"Oregon","Country":"US","Vintage":"2013","Vinyard":"Abacela","Name":"#14","Grape":"","Consumed In":"2015","Score":"2.5","Price":"21"},{"Color":"R","Region":"Bordeaux","Country":"France","Vintage":"2012","Vinyard":"David Beaulieu","Name":"","Grape":"merlot, cab","Consumed In":"2015","Score":"3.5","Price":"12"},{"Color":"R","Region":"Medoc","Country":"France","Vintage":"2011","Vinyard":"Chantemerle","Name":"","Grape":"merlot, cab","Consumed In":"2015","Score":"3.5","Price":"11.99"},{"Color":"R","Region":"Washington","Country":"US","Vintage":"2011","Vinyard":"Hyatt","Name":"","Grape":"merlot","Consumed In":"2015","Score":"4","Price":"13"},{"Color":"R","Region":"Tuscany","Country":"Italy","Vintage":"2012","Vinyard":"Rosso Dei Poggi","Name":"Rosso Dei Poggi","Grape":"sangiovese","Consumed In":"2015","Score":"3","Price":"12"},{"Color":"R","Region":"Tuscany","Country":"","Vintage":"2013","Vinyard":"Orizzonti","Name":"Montepulciano D\'Abruzzo","Grape":"","Consumed In":"2015","Score":"4.5","Price":"22"},{"Color":"R","Region":"Oregon","Country":"US","Vintage":"2010","Vinyard":"Abacelo","Name":"","Grape":"chiraz","Consumed In":"2015","Score":"3.5","Price":"7"},{"Color":"R","Region":"Tuscany","Country":"Italy","Vintage":"2012","Vinyard":"Ridolfi","Name":"Rosso Di Montalcino","Grape":"sangiovese","Consumed In":"2015","Score":"3.5","Price":"15"},{"Color":"W","Region":"Loire","Country":"France","Vintage":"2012","Vinyard":"Celestin Blobdeau","Name":"Sancerre Cuvee Des Moulins Bales","Grape":"sauvignon blanc","Consumed In":"2013","Score":"3","Price":"12"},{"Color":"R","Region":"Nappa","Country":"US","Vintage":"2012","Vinyard":"Belle Glos","Name":"Meiomi","Grape":"pinot noir","Consumed In":"2013","Score":"3","Price":"13"},{"Color":"R","Region":"France","Country":"France","Vintage":"2012","Vinyard":"Puech-Haut","Name":"Saint Drezery Prestige","Grape":"","Consumed In":"2013","Score":"3","Price":"13"},{"Color":"R","Region":"France","Country":"France","Vintage":"2011","Vinyard":"Puech-Haut","Name":"Saint Drezery Prestige","Grape":"","Consumed In":"2013","Score":"2","Price":"14"},{"Color":"W","Region":"Nappa","Country":"US","Vintage":"2012","Vinyard":"Honig","Name":"Sauvignon Blanc","Grape":"sauvignon blanc","Consumed In":"2014","Score":"4","Price":"14.5"},{"Color":"W","Region":"Nappa","Country":"US","Vintage":"2012","Vinyard":"Provenance","Name":"Uppercut North Coast","Grape":"sauvignon blanc","Consumed In":"2014","Score":"3","Price":"11"},{"Color":"R","Region":"Sicily","Country":"Italy","Vintage":"2011","Vinyard":"Baglio Di Pianetto","Name":"Nero d\'Avola","Grape":"","Consumed In":"2014","Score":"","Price":""},{"Color":"P","Region":"Truro","Country":"US","Vintage":"2013","Vinyard":"Truro Vineyards","Name":"Cape Blush","Grape":"","Consumed In":"2014","Score":"4","Price":"10"},{"Color":"W","Region":"Truro","Country":"US","Vintage":"2013","Vinyard":"Truro Vineyards","Name":"Pinot Grigio","Grape":"pinot griogio","Consumed In":"2014","Score ...

# %%
# What kind of data is this returning?
# ??? what is the .text doing
api_column_url = api_base_url + api_column
column_response = requests.get(api_column_url)
column_response.text
# Out:
# u'{"status":200,"success":true,"result":["","","","","Spice Trader","","#14","","","","Rosso Dei Poggi","Montepulciano D\'Abruzzo","","Rosso Di Montalcino","Sancerre Cuvee Des Moulins Bales","Meiomi","Saint Drezery Prestige","Saint Drezery Prestige","Sauvignon Blanc","Uppercut North Coast","Nero d\'Avola","Cape Blush","Pinot Grigio","Cru Classe","Domaine du Claouset","Sauvignon Blanc","Vinho Verde","Vincent Dampt","Albarino","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine","Lizs Wine","Michaels Wine","Chun Chun Bun Bun","Chun Hei Chow","Dylans Wine","Dylans Wine","Dylans Wine","Dylans Wine"]}'

# %% [markdown]
# #### Reading JSON

# %%
# converts the json data to a python dictionary
reponse_dict = json.loads(api_response.text)

# %% [markdown]
# #### What is the response of an API and what does it mean??

# %%
# What data was returned?
# returns a dictionary
reponse_dict
# Out:
# {u'result': [{u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'Portugal',
#    u'Grape': u'',
#    u'Name': u'',
#    u'Price': u'',
#    u'Region': u'Portugal',
#    u'Score': u'4',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Vinho Verde'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'France',
#    u'Grape': u'',
#    u'Name': u'',
#    u'Price': u'17.8',
#    u'Region': u'France',
#    u'Score': u'3',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Peyruchet'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'Oregon',
#    u'Grape': u'',
#    u'Name': u'',
#    u'Price': u'20',
#    u'Region': u'Oregon',
#    u'Score': u'3',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Abacela'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'Spain',
#    u'Grape': u'chardonay',
#    u'Name': u'',
#    u'Price': u'7',
#    u'Region': u'Spain',
#    u'Score': u'2.5',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Ochoa'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'chiraz, cab',
#    u'Name': u'Spice Trader',
#    u'Price': u'6',
#    u'Region': u'',
#    u'Score': u'3',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Heartland'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'cab',
#    u'Name': u'',
#    u'Price': u'13',
#    u'Region': u'California',
#    u'Score': u'3.5',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Crow Canyon'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'#14',
#    u'Price': u'21',
#    u'Region': u'Oregon',
#    u'Score': u'2.5',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Abacela'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'France',
#    u'Grape': u'merlot, cab',
#    u'Name': u'',
#    u'Price': u'12',
#    u'Region': u'Bordeaux',
#    u'Score': u'3.5',
#    u'Vintage': u'2012',
#    u'Vinyard': u'David Beaulieu'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'France',
#    u'Grape': u'merlot, cab',
#    u'Name': u'',
#    u'Price': u'11.99',
#    u'Region': u'Medoc',
#    u'Score': u'3.5',
#    u'Vintage': u'2011',
#    u'Vinyard': u'Chantemerle'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'merlot',
#    u'Name': u'',
#    u'Price': u'13',
#    u'Region': u'Washington',
#    u'Score': u'4',
#    u'Vintage': u'2011',
#    u'Vinyard': u'Hyatt'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'Italy',
#    u'Grape': u'sangiovese',
#    u'Name': u'Rosso Dei Poggi',
#    u'Price': u'12',
#    u'Region': u'Tuscany',
#    u'Score': u'3',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Rosso Dei Poggi'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'',
#    u'Grape': u'',
#    u'Name': u"Montepulciano D'Abruzzo",
#    u'Price': u'22',
#    u'Region': u'Tuscany',
#    u'Score': u'4.5',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Orizzonti'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'chiraz',
#    u'Name': u'',
#    u'Price': u'7',
#    u'Region': u'Oregon',
#    u'Score': u'3.5',
#    u'Vintage': u'2010',
#    u'Vinyard': u'Abacelo'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'Italy',
#    u'Grape': u'sangiovese',
#    u'Name': u'Rosso Di Montalcino',
#    u'Price': u'15',
#    u'Region': u'Tuscany',
#    u'Score': u'3.5',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Ridolfi'},
#   {u'Color': u'W',
#    u'Consumed In': u'2013',
#    u'Country': u'France',
#    u'Grape': u'sauvignon blanc',
#    u'Name': u'Sancerre Cuvee Des Moulins Bales',
#    u'Price': u'12',
#    u'Region': u'Loire',
#    u'Score': u'3',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Celestin Blobdeau'},
#   {u'Color': u'R',
#    u'Consumed In': u'2013',
#    u'Country': u'US',
#    u'Grape': u'pinot noir',
#    u'Name': u'Meiomi',
#    u'Price': u'13',
#    u'Region': u'Nappa',
#    u'Score': u'3',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Belle Glos'},
#   {u'Color': u'R',
#    u'Consumed In': u'2013',
#    u'Country': u'France',
#    u'Grape': u'',
#    u'Name': u'Saint Drezery Prestige',
#    u'Price': u'13',
#    u'Region': u'France',
#    u'Score': u'3',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Puech-Haut'},
#   {u'Color': u'R',
#    u'Consumed In': u'2013',
#    u'Country': u'France',
#    u'Grape': u'',
#    u'Name': u'Saint Drezery Prestige',
#    u'Price': u'14',
#    u'Region': u'France',
#    u'Score': u'2',
#    u'Vintage': u'2011',
#    u'Vinyard': u'Puech-Haut'},
#   {u'Color': u'W',
#    u'Consumed In': u'2014',
#    u'Country': u'US',
#    u'Grape': u'sauvignon blanc',
#    u'Name': u'Sauvignon Blanc',
#    u'Price': u'14.5',
#    u'Region': u'Nappa',
#    u'Score': u'4',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Honig'},
#   {u'Color': u'W',
#    u'Consumed In': u'2014',
#    u'Country': u'US',
#    u'Grape': u'sauvignon blanc',
#    u'Name': u'Uppercut North Coast',
#    u'Price': u'11',
#    u'Region': u'Nappa',
#    u'Score': u'3',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Provenance'},
#   {u'Color': u'R',
#    u'Consumed In': u'2014',
#    u'Country': u'Italy',
#    u'Grape': u'',
#    u'Name': u"Nero d'Avola",
#    u'Price': u'',
#    u'Region': u'Sicily',
#    u'Score': u'',
#    u'Vintage': u'2011',
#    u'Vinyard': u'Baglio Di Pianetto'},
#   {u'Color': u'P',
#    u'Consumed In': u'2014',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Cape Blush',
#    u'Price': u'10',
#    u'Region': u'Truro',
#    u'Score': u'4',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Truro Vineyards'},
#   {u'Color': u'W',
#    u'Consumed In': u'2014',
#    u'Country': u'US',
#    u'Grape': u'pinot griogio',
#    u'Name': u'Pinot Grigio',
#    u'Price': u'10',
#    u'Region': u'Truro',
#    u'Score': u'3',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Truro Vineyards'},
#   {u'Color': u'R',
#    u'Consumed In': u'2014',
#    u'Country': u'France',
#    u'Grape': u'',
#    u'Name': u'Cru Classe',
#    u'Price': u'',
#    u'Region': u'Provence',
#    u'Score': u'3.5',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Chateau de la Clapiere'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'France',
#    u'Grape': u'cabernet sauvignon',
#    u'Name': u'Domaine du Claouset',
#    u'Price': u'',
#    u'Region': u'Bordeaux',
#    u'Score': u'3',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Domaine du Claouset'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'',
#    u'Grape': u'sauvignon blanc',
#    u'Name': u'Sauvignon Blanc',
#    u'Price': u'',
#    u'Region': u'Napa',
#    u'Score': u'3.5',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Two Angels'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'Portugal',
#    u'Grape': u'',
#    u'Name': u'Vinho Verde',
#    u'Price': u'',
#    u'Region': u'Portugal',
#    u'Score': u'3.5',
#    u'Vintage': u'2013',
#    u'Vinyard': u'Mapreco'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'France',
#    u'Grape': u'Chablis, Vincent Dampt, Vaillons 1er (Burgundy, France) 2012 W/ Limestone taste',
#    u'Name': u'Vincent Dampt',
#    u'Price': u'35',
#    u'Region': u'Burgundy',
#    u'Score': u'4',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Vaillons'},
#   {u'Color': u'W',
#    u'Consumed In': u'2015',
#    u'Country': u'Spain',
#    u'Grape': u'Albarino, Granbazan (Rias Baixas) 2012',
#    u'Name': u'Albarino',
#    u'Price': u'15',
#    u'Region': u'Rias Baixas',
#    u'Score': u'4',
#    u'Vintage': u'2012',
#    u'Vinyard': u'Granbazan'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Lizs Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Michaels Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Chun Chun Bun Bun',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'allday bruh',
#    u'Country': u'China',
#    u'Grape': u'',
#    u'Name': u'Chun Hei Chow',
#    u'Price': u'200',
#    u'Region': u'China',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u'backyard'},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''},
#   {u'Color': u'R',
#    u'Consumed In': u'2015',
#    u'Country': u'US',
#    u'Grape': u'',
#    u'Name': u'Dylans Wine',
#    u'Price': u'200',
#    u'Region': u'CA',
#    u'Score': u'10',
#    u'Vintage': u'1973',
#    u'Vinyard': u''}],
#  u'status': 200,
#  u'success': True}

# %%
# .keys gives all the keys in the dictionary
reponse_dict.keys()
# Out:
# [u'status', u'result', u'success']

# %%
# ['<key>'] gives the value associated with that key in the dictionary
reponse_dict['result']
# Out:
# [{u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Portugal',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'',
#   u'Region': u'Portugal',
#   u'Score': u'4',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Vinho Verde'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'17.8',
#   u'Region': u'France',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Peyruchet'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Oregon',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'20',
#   u'Region': u'Oregon',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Abacela'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Spain',
#   u'Grape': u'chardonay',
#   u'Name': u'',
#   u'Price': u'7',
#   u'Region': u'Spain',
#   u'Score': u'2.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Ochoa'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'chiraz, cab',
#   u'Name': u'Spice Trader',
#   u'Price': u'6',
#   u'Region': u'',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Heartland'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'cab',
#   u'Name': u'',
#   u'Price': u'13',
#   u'Region': u'California',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Crow Canyon'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'#14',
#   u'Price': u'21',
#   u'Region': u'Oregon',
#   u'Score': u'2.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Abacela'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'merlot, cab',
#   u'Name': u'',
#   u'Price': u'12',
#   u'Region': u'Bordeaux',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'David Beaulieu'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'merlot, cab',
#   u'Name': u'',
#   u'Price': u'11.99',
#   u'Region': u'Medoc',
#   u'Score': u'3.5',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Chantemerle'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'merlot',
#   u'Name': u'',
#   u'Price': u'13',
#   u'Region': u'Washington',
#   u'Score': u'4',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Hyatt'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'Italy',
#   u'Grape': u'sangiovese',
#   u'Name': u'Rosso Dei Poggi',
#   u'Price': u'12',
#   u'Region': u'Tuscany',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Rosso Dei Poggi'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'',
#   u'Grape': u'',
#   u'Name': u"Montepulciano D'Abruzzo",
#   u'Price': u'22',
#   u'Region': u'Tuscany',
#   u'Score': u'4.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Orizzonti'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'chiraz',
#   u'Name': u'',
#   u'Price': u'7',
#   u'Region': u'Oregon',
#   u'Score': u'3.5',
#   u'Vintage': u'2010',
#   u'Vinyard': u'Abacelo'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'Italy',
#   u'Grape': u'sangiovese',
#   u'Name': u'Rosso Di Montalcino',
#   u'Price': u'15',
#   u'Region': u'Tuscany',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Ridolfi'},
#  {u'Color': u'W',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sancerre Cuvee Des Moulins Bales',
#   u'Price': u'12',
#   u'Region': u'Loire',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Celestin Blobdeau'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'US',
#   u'Grape': u'pinot noir',
#   u'Name': u'Meiomi',
#   u'Price': u'13',
#   u'Region': u'Nappa',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Belle Glos'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Saint Drezery Prestige',
#   u'Price': u'13',
#   u'Region': u'France',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Puech-Haut'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Saint Drezery Prestige',
#   u'Price': u'14',
#   u'Region': u'France',
#   u'Score': u'2',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Puech-Haut'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sauvignon Blanc',
#   u'Price': u'14.5',
#   u'Region': u'Nappa',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Honig'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Uppercut North Coast',
#   u'Price': u'11',
#   u'Region': u'Nappa',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Provenance'},
#  {u'Color': u'R',
#   u'Consumed In': u'2014',
#   u'Country': u'Italy',
#   u'Grape': u'',
#   u'Name': u"Nero d'Avola",
#   u'Price': u'',
#   u'Region': u'Sicily',
#   u'Score': u'',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Baglio Di Pianetto'},
#  {u'Color': u'P',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Cape Blush',
#   u'Price': u'10',
#   u'Region': u'Truro',
#   u'Score': u'4',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Truro Vineyards'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'pinot griogio',
#   u'Name': u'Pinot Grigio',
#   u'Price': u'10',
#   u'Region': u'Truro',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Truro Vineyards'},
#  {u'Color': u'R',
#   u'Consumed In': u'2014',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Cru Classe',
#   u'Price': u'',
#   u'Region': u'Provence',
#   u'Score': u'3.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Chateau de la Clapiere'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'cabernet sauvignon',
#   u'Name': u'Domaine du Claouset',
#   u'Price': u'',
#   u'Region': u'Bordeaux',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Domaine du Claouset'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sauvignon Blanc',
#   u'Price': u'',
#   u'Region': u'Napa',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Two Angels'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Portugal',
#   u'Grape': u'',
#   u'Name': u'Vinho Verde',
#   u'Price': u'',
#   u'Region': u'Portugal',
#   u'Score': u'3.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Mapreco'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'Chablis, Vincent Dampt, Vaillons 1er (Burgundy, France) 2012 W/ Limestone taste',
#   u'Name': u'Vincent Dampt',
#   u'Price': u'35',
#   u'Region': u'Burgundy',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Vaillons'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Spain',
#   u'Grape': u'Albarino, Granbazan (Rias Baixas) 2012',
#   u'Name': u'Albarino',
#   u'Price': u'15',
#   u'Region': u'Rias Baixas',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Granbazan'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Lizs Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Michaels Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Chun Chun Bun Bun',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'allday bruh',
#   u'Country': u'China',
#   u'Grape': u'',
#   u'Name': u'Chun Hei Chow',
#   u'Price': u'200',
#   u'Region': u'China',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u'backyard'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''}]

# %%
# [0] means the first element of the list
# each element of the list is also a dictionary. so the returned value is also of type dictionary
reponse_dict['result'][0]
# Out:
# {u'Color': u'W',
#  u'Consumed In': u'2015',
#  u'Country': u'Portugal',
#  u'Grape': u'',
#  u'Name': u'',
#  u'Price': u'',
#  u'Region': u'Portugal',
#  u'Score': u'4',
#  u'Vintage': u'2013',
#  u'Vinyard': u'Vinho Verde'}

# %% [markdown]
# #### Lets read the data into a DataFrame!

# %%
# converting the dictionary to a data frame
wine_df = pd.DataFrame(reponse_dict['result'])
wine_df.head()
# Out:
#   Color Consumed In   Country        Grape          Name Price    Region  \
# 0     W        2015  Portugal                                   Portugal
# 1     W        2015    France                             17.8    France
# 2     W        2015    Oregon                               20    Oregon
# 3     W        2015     Spain    chardonay                   7     Spain
# 4     R        2015        US  chiraz, cab  Spice Trader     6
#
#   Score Vintage      Vinyard
# 0     4    2013  Vinho Verde
# 1     3    2013    Peyruchet
# 2     3    2013      Abacela
# 3   2.5    2012        Ochoa
# 4     3    2012    Heartland

# %% [markdown]
# #### Pandas has great functions. We could just do it this way
#
# This sometimes works, but the data may need adjusting

# %%
# read_json can be helpful when the data is simple json
# why did we do this???
pd.read_json(api_response.text).head(2)
# Out:
#                                               result  status success
# 0  {u'Grape': u'', u'Name': u'', u'Color': u'W', ...     200    True
# 1  {u'Grape': u'', u'Name': u'', u'Color': u'W', ...     200    True

# %%
# Returns the data that I am interested in, which is result, and give its values
pd.read_json(api_response.text).result.values
# Out:
# array([ {u'Grape': u'', u'Name': u'', u'Color': u'W', u'Country': u'Portugal', u'Region': u'Portugal', u'Vinyard': u'Vinho Verde', u'Score': u'4', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u''},
#        {u'Grape': u'', u'Name': u'', u'Color': u'W', u'Country': u'France', u'Region': u'France', u'Vinyard': u'Peyruchet', u'Score': u'3', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u'17.8'},
#        {u'Grape': u'', u'Name': u'', u'Color': u'W', u'Country': u'Oregon', u'Region': u'Oregon', u'Vinyard': u'Abacela', u'Score': u'3', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u'20'},
#        {u'Grape': u'chardonay', u'Name': u'', u'Color': u'W', u'Country': u'Spain', u'Region': u'Spain', u'Vinyard': u'Ochoa', u'Score': u'2.5', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'7'},
#        {u'Grape': u'chiraz, cab', u'Name': u'Spice Trader', u'Color': u'R', u'Country': u'US', u'Region': u'', u'Vinyard': u'Heartland', u'Score': u'3', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'6'},
#        {u'Grape': u'cab', u'Name': u'', u'Color': u'R', u'Country': u'US', u'Region': u'California', u'Vinyard': u'Crow Canyon', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'13'},
#        {u'Grape': u'', u'Name': u'#14', u'Color': u'R', u'Country': u'US', u'Region': u'Oregon', u'Vinyard': u'Abacela', u'Score': u'2.5', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u'21'},
#        {u'Grape': u'merlot, cab', u'Name': u'', u'Color': u'R', u'Country': u'France', u'Region': u'Bordeaux', u'Vinyard': u'David Beaulieu', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'12'},
#        {u'Grape': u'merlot, cab', u'Name': u'', u'Color': u'R', u'Country': u'France', u'Region': u'Medoc', u'Vinyard': u'Chantemerle', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2011', u'Price': u'11.99'},
#        {u'Grape': u'merlot', u'Name': u'', u'Color': u'R', u'Country': u'US', u'Region': u'Washington', u'Vinyard': u'Hyatt', u'Score': u'4', u'Consumed In': u'2015', u'Vintage': u'2011', u'Price': u'13'},
#        {u'Grape': u'sangiovese', u'Name': u'Rosso Dei Poggi', u'Color': u'R', u'Country': u'Italy', u'Region': u'Tuscany', u'Vinyard': u'Rosso Dei Poggi', u'Score': u'3', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'12'},
#        {u'Grape': u'', u'Name': u"Montepulciano D'Abruzzo", u'Color': u'R', u'Country': u'', u'Region': u'Tuscany', u'Vinyard': u'Orizzonti', u'Score': u'4.5', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u'22'},
#        {u'Grape': u'chiraz', u'Name': u'', u'Color': u'R', u'Country': u'US', u'Region': u'Oregon', u'Vinyard': u'Abacelo', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2010', u'Price': u'7'},
#        {u'Grape': u'sangiovese', u'Name': u'Rosso Di Montalcino', u'Color': u'R', u'Country': u'Italy', u'Region': u'Tuscany', u'Vinyard': u'Ridolfi', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'15'},
#        {u'Grape': u'sauvignon blanc', u'Name': u'Sancerre Cuvee Des Moulins Bales', u'Color': u'W', u'Country': u'France', u'Region': u'Loire', u'Vinyard': u'Celestin Blobdeau', u'Score': u'3', u'Consumed In': u'2013', u'Vintage': u'2012', u'Price': u'12'},
#        {u'Grape': u'pinot noir', u'Name': u'Meiomi', u'Color': u'R', u'Country': u'US', u'Region': u'Nappa', u'Vinyard': u'Belle Glos', u'Score': u'3', u'Consumed In': u'2013', u'Vintage': u'2012', u'Price': u'13'},
#        {u'Grape': u'', u'Name': u'Saint Drezery Prestige', u'Color': u'R', u'Country': u'France', u'Region': u'France', u'Vinyard': u'Puech-Haut', u'Score': u'3', u'Consumed In': u'2013', u'Vintage': u'2012', u'Price': u'13'},
#        {u'Grape': u'', u'Name': u'Saint Drezery Prestige', u'Color': u'R', u'Country': u'France', u'Region': u'France', u'Vinyard': u'Puech-Haut', u'Score': u'2', u'Consumed In': u'2013', u'Vintage': u'2011', u'Price': u'14'},
#        {u'Grape': u'sauvignon blanc', u'Name': u'Sauvignon Blanc', u'Color': u'W', u'Country': u'US', u'Region': u'Nappa', u'Vinyard': u'Honig', u'Score': u'4', u'Consumed In': u'2014', u'Vintage': u'2012', u'Price': u'14.5'},
#        {u'Grape': u'sauvignon blanc', u'Name': u'Uppercut North Coast', u'Color': u'W', u'Country': u'US', u'Region': u'Nappa', u'Vinyard': u'Provenance', u'Score': u'3', u'Consumed In': u'2014', u'Vintage': u'2012', u'Price': u'11'},
#        {u'Grape': u'', u'Name': u"Nero d'Avola", u'Color': u'R', u'Country': u'Italy', u'Region': u'Sicily', u'Vinyard': u'Baglio Di Pianetto', u'Score': u'', u'Consumed In': u'2014', u'Vintage': u'2011', u'Price': u''},
#        {u'Grape': u'', u'Name': u'Cape Blush', u'Color': u'P', u'Country': u'US', u'Region': u'Truro', u'Vinyard': u'Truro Vineyards', u'Score': u'4', u'Consumed In': u'2014', u'Vintage': u'2013', u'Price': u'10'},
#        {u'Grape': u'pinot griogio', u'Name': u'Pinot Grigio', u'Color': u'W', u'Country': u'US', u'Region': u'Truro', u'Vinyard': u'Truro Vineyards', u'Score': u'3', u'Consumed In': u'2014', u'Vintage': u'2013', u'Price': u'10'},
#        {u'Grape': u'', u'Name': u'Cru Classe', u'Color': u'R', u'Country': u'France', u'Region': u'Provence', u'Vinyard': u'Chateau de la Clapiere', u'Score': u'3.5', u'Consumed In': u'2014', u'Vintage': u'2013', u'Price': u''},
#        {u'Grape': u'cabernet sauvignon', u'Name': u'Domaine du Claouset', u'Color': u'W', u'Country': u'France', u'Region': u'Bordeaux', u'Vinyard': u'Domaine du Claouset', u'Score': u'3', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u''},
#        {u'Grape': u'sauvignon blanc', u'Name': u'Sauvignon Blanc', u'Color': u'W', u'Country': u'', u'Region': u'Napa', u'Vinyard': u'Two Angels', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u''},
#        {u'Grape': u'', u'Name': u'Vinho Verde', u'Color': u'W', u'Country': u'Portugal', u'Region': u'Portugal', u'Vinyard': u'Mapreco', u'Score': u'3.5', u'Consumed In': u'2015', u'Vintage': u'2013', u'Price': u''},
#        {u'Grape': u'Chablis, Vincent Dampt, Vaillons 1er (Burgundy, France) 2012 W/ Limestone taste', u'Name': u'Vincent Dampt', u'Color': u'W', u'Country': u'France', u'Region': u'Burgundy', u'Vinyard': u'Vaillons', u'Score': u'4', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'35'},
#        {u'Grape': u'Albarino, Granbazan (Rias Baixas) 2012', u'Name': u'Albarino', u'Color': u'W', u'Country': u'Spain', u'Region': u'Rias Baixas', u'Vinyard': u'Granbazan', u'Score': u'4', u'Consumed In': u'2015', u'Vintage': u'2012', u'Price': u'15'},
#        {u'Grape': u'', u'Name': u'Dylans Wine', u'Color': u'R', u'Country': u'US', u'Region': u'CA', u'Vinyard': u'', u'Score': u'10', u'Consumed In': u'2015', u'Vintage': u'1973', u'Price': u'200'}], dtype=object)

# %%
# Now I want this data in a list format
list(pd.read_json(api_response.text).result.values)
# Out:
# [{u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Portugal',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'',
#   u'Region': u'Portugal',
#   u'Score': u'4',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Vinho Verde'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'17.8',
#   u'Region': u'France',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Peyruchet'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Oregon',
#   u'Grape': u'',
#   u'Name': u'',
#   u'Price': u'20',
#   u'Region': u'Oregon',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Abacela'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Spain',
#   u'Grape': u'chardonay',
#   u'Name': u'',
#   u'Price': u'7',
#   u'Region': u'Spain',
#   u'Score': u'2.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Ochoa'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'chiraz, cab',
#   u'Name': u'Spice Trader',
#   u'Price': u'6',
#   u'Region': u'',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Heartland'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'cab',
#   u'Name': u'',
#   u'Price': u'13',
#   u'Region': u'California',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Crow Canyon'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'#14',
#   u'Price': u'21',
#   u'Region': u'Oregon',
#   u'Score': u'2.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Abacela'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'merlot, cab',
#   u'Name': u'',
#   u'Price': u'12',
#   u'Region': u'Bordeaux',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'David Beaulieu'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'merlot, cab',
#   u'Name': u'',
#   u'Price': u'11.99',
#   u'Region': u'Medoc',
#   u'Score': u'3.5',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Chantemerle'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'merlot',
#   u'Name': u'',
#   u'Price': u'13',
#   u'Region': u'Washington',
#   u'Score': u'4',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Hyatt'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'Italy',
#   u'Grape': u'sangiovese',
#   u'Name': u'Rosso Dei Poggi',
#   u'Price': u'12',
#   u'Region': u'Tuscany',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Rosso Dei Poggi'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'',
#   u'Grape': u'',
#   u'Name': u"Montepulciano D'Abruzzo",
#   u'Price': u'22',
#   u'Region': u'Tuscany',
#   u'Score': u'4.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Orizzonti'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'chiraz',
#   u'Name': u'',
#   u'Price': u'7',
#   u'Region': u'Oregon',
#   u'Score': u'3.5',
#   u'Vintage': u'2010',
#   u'Vinyard': u'Abacelo'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'Italy',
#   u'Grape': u'sangiovese',
#   u'Name': u'Rosso Di Montalcino',
#   u'Price': u'15',
#   u'Region': u'Tuscany',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Ridolfi'},
#  {u'Color': u'W',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sancerre Cuvee Des Moulins Bales',
#   u'Price': u'12',
#   u'Region': u'Loire',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Celestin Blobdeau'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'US',
#   u'Grape': u'pinot noir',
#   u'Name': u'Meiomi',
#   u'Price': u'13',
#   u'Region': u'Nappa',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Belle Glos'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Saint Drezery Prestige',
#   u'Price': u'13',
#   u'Region': u'France',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Puech-Haut'},
#  {u'Color': u'R',
#   u'Consumed In': u'2013',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Saint Drezery Prestige',
#   u'Price': u'14',
#   u'Region': u'France',
#   u'Score': u'2',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Puech-Haut'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sauvignon Blanc',
#   u'Price': u'14.5',
#   u'Region': u'Nappa',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Honig'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Uppercut North Coast',
#   u'Price': u'11',
#   u'Region': u'Nappa',
#   u'Score': u'3',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Provenance'},
#  {u'Color': u'R',
#   u'Consumed In': u'2014',
#   u'Country': u'Italy',
#   u'Grape': u'',
#   u'Name': u"Nero d'Avola",
#   u'Price': u'',
#   u'Region': u'Sicily',
#   u'Score': u'',
#   u'Vintage': u'2011',
#   u'Vinyard': u'Baglio Di Pianetto'},
#  {u'Color': u'P',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Cape Blush',
#   u'Price': u'10',
#   u'Region': u'Truro',
#   u'Score': u'4',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Truro Vineyards'},
#  {u'Color': u'W',
#   u'Consumed In': u'2014',
#   u'Country': u'US',
#   u'Grape': u'pinot griogio',
#   u'Name': u'Pinot Grigio',
#   u'Price': u'10',
#   u'Region': u'Truro',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Truro Vineyards'},
#  {u'Color': u'R',
#   u'Consumed In': u'2014',
#   u'Country': u'France',
#   u'Grape': u'',
#   u'Name': u'Cru Classe',
#   u'Price': u'',
#   u'Region': u'Provence',
#   u'Score': u'3.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Chateau de la Clapiere'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'cabernet sauvignon',
#   u'Name': u'Domaine du Claouset',
#   u'Price': u'',
#   u'Region': u'Bordeaux',
#   u'Score': u'3',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Domaine du Claouset'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'',
#   u'Grape': u'sauvignon blanc',
#   u'Name': u'Sauvignon Blanc',
#   u'Price': u'',
#   u'Region': u'Napa',
#   u'Score': u'3.5',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Two Angels'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Portugal',
#   u'Grape': u'',
#   u'Name': u'Vinho Verde',
#   u'Price': u'',
#   u'Region': u'Portugal',
#   u'Score': u'3.5',
#   u'Vintage': u'2013',
#   u'Vinyard': u'Mapreco'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'France',
#   u'Grape': u'Chablis, Vincent Dampt, Vaillons 1er (Burgundy, France) 2012 W/ Limestone taste',
#   u'Name': u'Vincent Dampt',
#   u'Price': u'35',
#   u'Region': u'Burgundy',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Vaillons'},
#  {u'Color': u'W',
#   u'Consumed In': u'2015',
#   u'Country': u'Spain',
#   u'Grape': u'Albarino, Granbazan (Rias Baixas) 2012',
#   u'Name': u'Albarino',
#   u'Price': u'15',
#   u'Region': u'Rias Baixas',
#   u'Score': u'4',
#   u'Vintage': u'2012',
#   u'Vinyard': u'Granbazan'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Lizs Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Michaels Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Chun Chun Bun Bun',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'allday bruh',
#   u'Country': u'China',
#   u'Grape': u'',
#   u'Name': u'Chun Hei Chow',
#   u'Price': u'200',
#   u'Region': u'China',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u'backyard'},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''},
#  {u'Color': u'R',
#   u'Consumed In': u'2015',
#   u'Country': u'US',
#   u'Grape': u'',
#   u'Name': u'Dylans Wine',
#   u'Price': u'200',
#   u'Region': u'CA',
#   u'Score': u'10',
#   u'Vintage': u'1973',
#   u'Vinyard': u''}]

# %%
wine_df = pd.DataFrame(list(pd.read_json(api_response.text).result.values))
wine_df.head(2)
# Out:
#   Color Consumed In   Country Grape Name Price    Region Score Vintage  \
# 0     W        2015  Portugal                   Portugal     4    2013
# 1     W        2015    France             17.8    France     3    2013
#
#        Vinyard
# 0  Vinho Verde
# 1    Peyruchet

# %%
# This returns a dictionary
wine_df.head(2).to_json()
# Out:
# '{"Color":{"0":"W","1":"W"},"Consumed In":{"0":"2015","1":"2015"},"Country":{"0":"Portugal","1":"France"},"Grape":{"0":"","1":""},"Name":{"0":"","1":""},"Price":{"0":"","1":"17.8"},"Region":{"0":"Portugal","1":"France"},"Score":{"0":"4","1":"3"},"Vintage":{"0":"2013","1":"2013"},"Vinyard":{"0":"Vinho Verde","1":"Peyruchet"}}'

# %%
# this created a list of dictionaries
wine_df.head(2).to_json(orient='records')
# Out:
# '[{"Color":"W","Consumed In":"2015","Country":"Portugal","Grape":"","Name":"","Price":"","Region":"Portugal","Score":"4","Vintage":"2013","Vinyard":"Vinho Verde"},{"Color":"W","Consumed In":"2015","Country":"France","Grape":"","Name":"","Price":"17.8","Region":"France","Score":"3","Vintage":"2013","Vinyard":"Peyruchet"}]'

# %%
api_base_yelp_url = "https://api.yelp.com/v2"
api_yelp_column = "/column/Name"

# %%
api_column_yelp_url = api_base_yelp_url + api_yelp_column
api_yelp_response = requests.get(api_column_yelp_url)
api_yelp_response.text
# Out:
# u'<!doctype html>\n<!--[if IE 7 ]>    <html class="ie7 ie ltie9 ltie8"> <![endif]-->\n<!--[if IE 8 ]>    <html class="ie8 ie ltie9"> <![endif]-->\n<!--[if IE 9 ]>    <html class="ie9 ie"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html> <!--<![endif]-->\n<head>\n    <meta charset="utf-8">\n\n        <title>Yelp - Page not found (Error 404)</title>\n\n    <meta http-equiv="Cache-Control" content="no-cache">\n    <meta http-equiv="Expires" content="0">\n    <link rel="stylesheet" href="https://s3-media1.fl.yelpcdn.com/assets/2/www/css/cfc1eb774fde/error-pkg.css">\n</head>\n<body class="ytype error-page">\n    <span class="offscreen error-code">404</span>\n    <div class="wrap">\n                    \n\n\n\n\n\n        <div class="main-header main-content-wrap js-main-header main-header--simple">\n            <div class="content-container clearfix">\n                <div class="arrange arrange--18 main-header_arrange arrange--middle">\n\n                            \n\n        <div class="arrange_unit main-header--full_arrange_unit">\n            <h1 class="main-header_logo" id="logo">\n                <a href="/">Yelp</a>\n            </h1>\n        </div>\n\n\n\n                </div>\n            </div>\n        </div>\n\n        <div class="error-wrap">\n            <div class="content-container content-container--error clearfix">\n                <div class="media-body">\n                    <h2 class="headline">\n                            <span class="page-status">404 error.</span>\n\n                            Doggone it! The page you\u2019re looking for cannot be found.\n\n                    </h2>\n\n                    <p class="message">\n                            Detective Darwin is hot on the case of the missing webpage!\n\n    While he\'s sniffing out the problem, you should either <a href="http://www.yelp.com/">go home</a> or search for what you need below. Elementary, my dear Yelper.\n                    </p>\n\n                        <form action="/search" class="yform flex-container">\n                            <label class="flex-box">\n                                <span class="label-text">Search for</span>\n                                <input type="text" name="find_desc" autofocus>\n                            </label>\n                            <label class="flex-box">\n                                <span class="label-text">Near</span>\n                                <input type="text" name="find_loc" id="find-loc">\n                            </label>\n                            <div class="button-container">\n                                <button title="Search" type="submit" value="submit" class="ybtn ybtn-primary ybtn-small search-submit ytype"><span><i  class="i ig-common i-search-common"></i></span></button>\n                            </div>\n                        </form>\n                </div>\n            </div>\n        </div>\n\n    <div class="main-content-wrap main-content-wrap--separated">\n        <div class="content-container">\n            <div class="main-footer">\n    <div class="nav-links">\n            <div class="footer-menu footer-menu--inline footer-menu--bordered">\n        <ul class="footer-menu_list">\n            <li class="footer-menu_item is-highlighted">Navigate</li>\n            <li class="footer-menu_item">\n                <a href="http://www.yelp.com/">Welcome</a>\n            </li>\n            <li class="footer-menu_item">\n                <a href="http://www.yelp.com/user_details">About Me</a>\n            </li>\n            <li class="footer-menu_item">\n                <a href="https://www.yelp.com/writeareview">Write a Review</a>\n            </li>\n            <li class="footer-menu_item">\n                <a href="http://www.yelp.com/find_friends/">Invite Friends</a>\n            </li>\n            <li class="footer-menu_item">\n                <a href="http://www.yelp.com/mail">Messaging</a>\n            </li>\n            <li class="foot ...

# %% [markdown]
# #### Writing to an API using PUT
# You will rarely need to do this

# %%
# Send data to an API
post_data = {
    'Grape' : ''
    , 'Name' : 'Dylans Wine'
    , 'Color' : 'R'
    , 'Country' : 'US'
    , 'Region' : 'CA'
    , 'Vinyard' : ''
    , 'Score' : '10'
    , 'Consumed In' : '2015'
    , 'Vintage' : '1973'
    , 'Price' : '200'
    }
requests.post(api_base_url, data=post_data)
# Out:
# <Response [201]>

# %% [markdown]
# ### Exercise 1
#     - Either with your own google doc or a different API
#     - Extract some data using requests
#     - Pull the data into a DataFrame
#     - Search For missing data
#         - Is there any missing data you can clean?
#         - Is there any data you can just remove?
#     - Summarize the data
#         - Try using describe, min, max, mean, var
#         - What are the unique values and can you do anything with the text?
#             Hint: Try using pd.get_dummies
#     - Bonus: Create some visualizations form this data
#     - Bonus: Try using sheetsu to push new data to the google doc (requests.post)

# %%
# get the api
api_base_url = "https://sheetsu.com/apis/ed121700"
api_column = "/column/Name"

# %%
# extract data from the api
api_column_url = api_base_url + api_column
api_response = requests.get(api_base_url)
api_response.text
# Out:
# u'{"status":200,"success":true,"result":[{"Name":"Nomi1","Age":"","Height":"140","Location":"SF1"},{"Name":"Nomi2","Age":"21","Height":"141","Location":"SF2"},{"Name":"Nomi3","Age":"22","Height":"142","Location":"SF3"},{"Name":"Nomi4","Age":"23","Height":"143","Location":"SF4"},{"Name":"Nomi5","Age":"24","Height":"144","Location":"SF5"},{"Name":"Nomi6","Age":"25","Height":"145","Location":"SF6"},{"Name":"Nomi7","Age":"26","Height":"146","Location":"SF7"},{"Name":"Nomi8","Age":"27","Height":"147","Location":"SF8"},{"Name":"Nomi9","Age":"28","Height":"148","Location":"SF9"},{"Name":"Nomi10","Age":"29","Height":"149","Location":"SF10"},{"Name":"Nomi11","Age":"","Height":"150","Location":"SF11"},{"Name":"Nomi12","Age":"31","Height":"151","Location":"SF12"},{"Name":"Nomi13","Age":"32","Height":"152","Location":"SF13"},{"Name":"Nomi14","Age":"33","Height":"153","Location":"SF14"},{"Name":"Nomi15","Age":"34","Height":"154","Location":"SF15"},{"Name":"Nomi16","Age":"35","Height":"155","Location":"SF16"},{"Name":"Nomi17","Age":"36","Height":"156","Location":"SF17"},{"Name":"Nomi18","Age":"37","Height":"157","Location":"SF18"},{"Name":"Nomi19","Age":"38","Height":"158","Location":"SF19"},{"Name":"Nomi20","Age":"39","Height":"159","Location":"SF20"},{"Name":"Nomi21","Age":"40","Height":"160","Location":"SF21"},{"Name":"Nomi22","Age":"41","Height":"161","Location":"SF22"},{"Name":"Nomi23","Age":"42","Height":"162","Location":"SF23"},{"Name":"Nomi24","Age":"43","Height":"163","Location":"SF24"},{"Name":"Nomi25","Age":"44","Height":"164","Location":"SF25"},{"Name":"Nomi26","Age":"45","Height":"165","Location":"SF26"},{"Name":"Nomi27","Age":"46","Height":"166","Location":"SF27"},{"Name":"Nomi28","Age":"47","Height":"167","Location":"SF28"},{"Name":"Nomi29","Age":"48","Height":"168","Location":"SF29"},{"Name":"Nomi30","Age":"49","Height":"169","Location":"SF30"}]}'

# %%
# convert the resulted json to a dictionary, coz pandas works better this way
response_dict = json.loads(api_response.text)

# %%
response_dict
# Out:
# {u'result': [{u'Age': u'',
#    u'Height': u'140',
#    u'Location': u'SF1',
#    u'Name': u'Nomi1'},
#   {u'Age': u'21', u'Height': u'141', u'Location': u'SF2', u'Name': u'Nomi2'},
#   {u'Age': u'22', u'Height': u'142', u'Location': u'SF3', u'Name': u'Nomi3'},
#   {u'Age': u'23', u'Height': u'143', u'Location': u'SF4', u'Name': u'Nomi4'},
#   {u'Age': u'24', u'Height': u'144', u'Location': u'SF5', u'Name': u'Nomi5'},
#   {u'Age': u'25', u'Height': u'145', u'Location': u'SF6', u'Name': u'Nomi6'},
#   {u'Age': u'26', u'Height': u'146', u'Location': u'SF7', u'Name': u'Nomi7'},
#   {u'Age': u'27', u'Height': u'147', u'Location': u'SF8', u'Name': u'Nomi8'},
#   {u'Age': u'28', u'Height': u'148', u'Location': u'SF9', u'Name': u'Nomi9'},
#   {u'Age': u'29', u'Height': u'149', u'Location': u'SF10', u'Name': u'Nomi10'},
#   {u'Age': u'', u'Height': u'150', u'Location': u'SF11', u'Name': u'Nomi11'},
#   {u'Age': u'31', u'Height': u'151', u'Location': u'SF12', u'Name': u'Nomi12'},
#   {u'Age': u'32', u'Height': u'152', u'Location': u'SF13', u'Name': u'Nomi13'},
#   {u'Age': u'33', u'Height': u'153', u'Location': u'SF14', u'Name': u'Nomi14'},
#   {u'Age': u'34', u'Height': u'154', u'Location': u'SF15', u'Name': u'Nomi15'},
#   {u'Age': u'35', u'Height': u'155', u'Location': u'SF16', u'Name': u'Nomi16'},
#   {u'Age': u'36', u'Height': u'156', u'Location': u'SF17', u'Name': u'Nomi17'},
#   {u'Age': u'37', u'Height': u'157', u'Location': u'SF18', u'Name': u'Nomi18'},
#   {u'Age': u'38', u'Height': u'158', u'Location': u'SF19', u'Name': u'Nomi19'},
#   {u'Age': u'39', u'Height': u'159', u'Location': u'SF20', u'Name': u'Nomi20'},
#   {u'Age': u'40', u'Height': u'160', u'Location': u'SF21', u'Name': u'Nomi21'},
#   {u'Age': u'41', u'Height': u'161', u'Location': u'SF22', u'Name': u'Nomi22'},
#   {u'Age': u'42', u'Height': u'162', u'Location': u'SF23', u'Name': u'Nomi23'},
#   {u'Age': u'43', u'Height': u'163', u'Location': u'SF24', u'Name': u'Nomi24'},
#   {u'Age': u'44', u'Height': u'164', u'Location': u'SF25', u'Name': u'Nomi25'},
#   {u'Age': u'45', u'Height': u'165', u'Location': u'SF26', u'Name': u'Nomi26'},
#   {u'Age': u'46', u'Height': u'166', u'Location': u'SF27', u'Name': u'Nomi27'},
#   {u'Age': u'47', u'Height': u'167', u'Location': u'SF28', u'Name': u'Nomi28'},
#   {u'Age': u'48', u'Height': u'168', u'Location': u'SF29', u'Name': u'Nomi29'},
#   {u'Age': u'49',
#    u'Height': u'169',
#    u'Location': u'SF30',
#    u'Name': u'Nomi30'}],
#  u'status': 200,
#  u'success': True}

# %%
# converting my dictionary to a data frame
mysample_df = pd.DataFrame(response_dict['result'])

# %%
mysample_df
# Out:
#    Age Height Location    Name
# 0         140      SF1   Nomi1
# 1   21    141      SF2   Nomi2
# 2   22    142      SF3   Nomi3
# 3   23    143      SF4   Nomi4
# 4   24    144      SF5   Nomi5
# 5   25    145      SF6   Nomi6
# 6   26    146      SF7   Nomi7
# 7   27    147      SF8   Nomi8
# 8   28    148      SF9   Nomi9
# 9   29    149     SF10  Nomi10
# 10        150     SF11  Nomi11
# 11  31    151     SF12  Nomi12
# 12  32    152     SF13  Nomi13
# 13  33    153     SF14  Nomi14
# 14  34    154     SF15  Nomi15
# 15  35    155     SF16  Nomi16
# 16  36    156     SF17  Nomi17
# 17  37    157     SF18  Nomi18
# 18  38    158     SF19  Nomi19
# 19  39    159     SF20  Nomi20
# 20  40    160     SF21  Nomi21
# 21  41    161     SF22  Nomi22
# 22  42    162     SF23  Nomi23
# 23  43    163     SF24  Nomi24
# 24  44    164     SF25  Nomi25
# 25  45    165     SF26  Nomi26
# 26  46    166     SF27  Nomi27
# 27  47    167     SF28  Nomi28
# 28  48    168     SF29  Nomi29
# 29  49    169     SF30  Nomi30

# %%
import numpy as np

# %%
mysample_df = mysample_df.replace('', np.nan)

# %%
# finding the nulls
mysample_df[mysample_df.Age.isnull()]
# Out:
#     Age Height Location    Name
# 0   NaN    140      SF1   Nomi1
# 10  NaN    150     SF11  Nomi11

# %%
mysample_df.Age = mysample_df.Age.astype(float)

# %%
# get the average age
avg_age = mysample_df['Age'].mean()

# %%
avg_age
# Out:
# 35.17857142857143

# %%
# replace all the nulls with the avg age
mysample_df['Age'].fillna(value=avg_age, inplace=True)

# %%
mysample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 4 columns):
# Age         30 non-null float64
# Height      30 non-null object
# Location    30 non-null object
# Name        30 non-null object
# dtypes: float64(1), object(3)
# memory usage: 1.2+ KB

# %%
mysample_df
# Out:
#           Age Height Location    Name
# 0   35.178571    140      SF1   Nomi1
# 1   21.000000    141      SF2   Nomi2
# 2   22.000000    142      SF3   Nomi3
# 3   23.000000    143      SF4   Nomi4
# 4   24.000000    144      SF5   Nomi5
# 5   25.000000    145      SF6   Nomi6
# 6   26.000000    146      SF7   Nomi7
# 7   27.000000    147      SF8   Nomi8
# 8   28.000000    148      SF9   Nomi9
# 9   29.000000    149     SF10  Nomi10
# 10  35.178571    150     SF11  Nomi11
# 11  31.000000    151     SF12  Nomi12
# 12  32.000000    152     SF13  Nomi13
# 13  33.000000    153     SF14  Nomi14
# 14  34.000000    154     SF15  Nomi15
# 15  35.000000    155     SF16  Nomi16
# 16  36.000000    156     SF17  Nomi17
# 17  37.000000    157     SF18  Nomi18
# 18  38.000000    158     SF19  Nomi19
# 19  39.000000    159     SF20  Nomi20
# 20  40.000000    160     SF21  Nomi21
# 21  41.000000    161     SF22  Nomi22
# 22  42.000000    162     SF23  Nomi23
# 23  43.000000    163     SF24  Nomi24
# 24  44.000000    164     SF25  Nomi25
# 25  45.000000    165     SF26  Nomi26
# 26  46.000000    166     SF27  Nomi27
# 27  47.000000    167     SF28  Nomi28
# 28  48.000000    168     SF29  Nomi29
# 29  49.000000    169     SF30  Nomi30

# %% [markdown]
# ## Kimono Labs

# %% [markdown]
# Web scraping with the Kimono Labs API
#
# https://www.kimonolabs.com/
#
# Kimono labs has undergone a bit of a redesign in recent months and now encourages crawling for all the data you'd want ahead of time and extracting the batch in a series of calls. To create an api, follow the kimono labs walkthrough. To generate a large amount of data like we will here, a series of screenshot walkthroughs have been added.
#
# After creating an API from an advanced search query as walked through in class, navigate to the Crawl Setup tab from the API management page in kimono.

# %%
from IPython.display import Image
Image(filename='KL_Crawl_Setup.png')

# %% [markdown]
# Change the crawl strategy to Generated URL List

# %%
from IPython.display import Image
Image(filename='KL_Generated_URL_List.png')

# %% [markdown]
# From here you can automatically generate a list of pages to extract data from, with the caveat that the pages you are navigating all have roughly the same structure. Here we are going to look for the top boxoffice_gross_us from 1990 to 2014.

# %%
from IPython.display import Image
Image(filename='KL_Parameter_range.png')

# %%
#After you let the data crawl the page, you can update the data here.

import json
import urllib

results = json.load(urllib.urlopen("https://www.kimonolabs.com/api/eb81bu78?apikey=4WrTjTsFDGmHCLnYrAXeSLIjJYcfrG7j"))
results

# %%
your_key = "4WrTjTsFDGmHCLnYrAXeSLIjJYcfrG7j"
your_endpoint = "eb81bu78"
import json
import urllib
import pandas as pd

def getMovies(api_key=your_key,endpoint=your_endpoint):
    """
    Creates list of top 50 movies by gross box office
    sales for a with ratings and sales
    """
    
    movies, ratings, sales, years = [], [], [], []
    #Remember to replace this link with the link to your specifc API
    url = "https://www.kimonolabs.com/api/{}?".format(endpoint) + \
            "apikey={}".format(api_key)
    data = json.load(urllib.urlopen(url))
    
    # Iterate through json object to collect data
    for n in xrange(data['count']):
        n_title = data['results']['collection1'][n]['title']['text']
        n_rating = float(data['results']['collection1'][n]['rating'])
        n_sales = float(data['results']['collection1'][n]['sales'][1:-1])
        n_year = int(data['results']['collection1'][n]['url'][-4:])
        movies.append(n_title)
        ratings.append(n_rating)
        sales.append(n_sales)
        years.append(n_year)
    data = pd.DataFrame({'movie':movies,'rating':ratings,'sales_in_M':sales,'year':years})
    
    return data
movies = getMovies()
movies.head()

# %% [markdown]
# Note a few things: The function we wrote relies on extracting pieces of a string and converting them to numeric types. Here, the year can be extracted from the url used to generate the movies, so we use the slice `[-4:]` to identify that. Similarly, the gross cost comes out as $##M, so we know we never want the first or last value. Thus the slice `[1:-1]` is correct.

# %% [markdown]
# ###Exercise 2.1
# Build your own api via kimono at https://www.kimonolabs.com/. Create the api we created in class to call the data.
#
# What were the average sales in 1995?
# What was the average rating?

# %% [markdown]
# ###Bonus
# What were the average sales for the 90s? How does that differ from the 2000s?
